# %% [markdown]
# # Data Science with Pandas & Visualization
#
# This notebook is based on the provided slides.
# It covers data loading, exploration, cleaning, manipulation, groupby & aggregations, and visualization using **Pandas**, **Matplotlib**, and **Seaborn**.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (2.3.2)

# %%
import pandas as pd

import numpy as np

# %%
np.nan #not a number
# Out:
# nan

# %% [markdown]
# ## Loading Data
# We will create a sample dataset for demonstration.

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Helen"],
    "Age": [25, 30, 35, np.nan, 40, 28, 33, 29],
    "Height": [165, 180, 175, 170, np.nan, 178, 160, 158],
    "Weight": [55, 78, 72, np.nan, 68, 80, 54, 50],
    "Gender": ["F", "M", "M", "M", "F", "M", "F", "F"]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name   Age  Height  Weight Gender
# 0    Alice  25.0   165.0    55.0      F
# 1      Bob  30.0   180.0    78.0      M
# 2  Charlie  35.0   175.0    72.0      M
# 3    David   NaN   170.0     NaN      M
# 4      Eva  40.0     NaN    68.0      F
# 5    Frank  28.0   178.0    80.0      M
# 6    Grace  33.0   160.0    54.0      F
# 7    Helen  29.0   158.0    50.0      F

# %%
df.to_csv("data.csv")

# %%
# %ls #is an IPython magic command (works in Jupyter Notebook or IPython shell) — it lists the files and folders in your current working directory, similar to the ls command in Linux or macOS.
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is CC21-38D8
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
#
#
#  Directory of C:\Users\olumi\Desktop\Training
# File Not Found

# %%
df = pd.read_csv("data.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Height', 'Weight', 'Gender'], dtype='object')

# %%
df_fil = df[['Name', 'Age', 'Height', 'Weight', 'Gender']]

# %%
df_fil
# Out:
#       Name   Age  Height  Weight Gender
# 0    Alice  25.0   165.0    55.0      F
# 1      Bob  30.0   180.0    78.0      M
# 2  Charlie  35.0   175.0    72.0      M
# 3    David   NaN   170.0     NaN      M
# 4      Eva  40.0     NaN    68.0      F
# 5    Frank  28.0   178.0    80.0      M
# 6    Grace  33.0   160.0    54.0      F
# 7    Helen  29.0   158.0    50.0      F

# %%
df_fil2 = df.drop(["Unnamed: 0","Height" ], axis=1)

# %%
df_fil2
# Out:
#       Name   Age  Weight Gender
# 0    Alice  25.0    55.0      F
# 1      Bob  30.0    78.0      M
# 2  Charlie  35.0    72.0      M
# 3    David   NaN     NaN      M
# 4      Eva  40.0    68.0      F
# 5    Frank  28.0    80.0      M
# 6    Grace  33.0    54.0      F
# 7    Helen  29.0    50.0      F

# %%
df.head(1)
# Out:
#    Unnamed: 0   Name   Age  Height  Weight Gender
# 0           0  Alice  25.0   165.0    55.0      F

# %%
df.tail(4)
# Out:
#    Unnamed: 0   Name   Age  Height  Weight Gender
# 4           4    Eva  40.0     NaN    68.0      F
# 5           5  Frank  28.0   178.0    80.0      M
# 6           6  Grace  33.0   160.0    54.0      F
# 7           7  Helen  29.0   158.0    50.0      F

# %%
df
# Out:
#    Unnamed: 0     Name   Age  Height  Weight Gender
# 0           0    Alice  25.0   165.0    55.0      F
# 1           1      Bob  30.0   180.0    78.0      M
# 2           2  Charlie  35.0   175.0    72.0      M
# 3           3    David   NaN   170.0     NaN      M
# 4           4      Eva  40.0     NaN    68.0      F
# 5           5    Frank  28.0   178.0    80.0      M
# 6           6    Grace  33.0   160.0    54.0      F
# 7           7    Helen  29.0   158.0    50.0      F

# %%
# Sample dataset


df = pd.DataFrame(data)
df.to_csv("sample_data.csv", index=False)

# Load dataset from CSV
df = pd.read_csv("sample_data.csv")
df.head()
# Out:
#       Name   Age  Height  Weight Gender
# 0    Alice  25.0   165.0    55.0      F
# 1      Bob  30.0   180.0    78.0      M
# 2  Charlie  35.0   175.0    72.0      M
# 3    David   NaN   170.0     NaN      M
# 4      Eva  40.0     NaN    68.0      F

# %% [markdown]
# ## Exploring Data

# %%
print("Head:")
print(df.head())

print("\nInfo:")
print(df.info())

print("\nDescribe:")
print(df.describe())

print("\nShape:", df.shape)
print("Columns:", df.columns.tolist())
print("Data types:\n", df.dtypes)
# Out:
# Head:
#       Name   Age  Height  Weight Gender
# 0    Alice  25.0   165.0    55.0      F
# 1      Bob  30.0   180.0    78.0      M
# 2  Charlie  35.0   175.0    72.0      M
# 3    David   NaN   170.0     NaN      M
# 4      Eva  40.0     NaN    68.0      F
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     7 non-null      float64
#  2   Height  7 non-null      float64
#  3   Weight  7 non-null      float64
#  4   Gender  8 non-null      object
# dtypes: float64(3), object(2)
# memory usage: 452.0+ bytes
# None
#
# Describe:
#              Age      Height     Weight
# count   7.000000    7.000000   7.000000
# mean   31.428571  169.428571  65.285714
# std     4.995236    8.715066  12.229940
# min    25.000000  158.000000  50.000000
# 25%    28.500000  162.500000  54.500000
# 50%    30.000000  170.000000  68.000000
# 75%    34.000000  176.500000  75.000000
# max    40.000000  180.000000  80.000000
#
# Shape: (8, 5)
# Columns: ['Name', 'Age', 'Height', 'Weight', 'Gender']
# Data types:
#  Name       object
# Age       float64
# Height    float64
# Weight    float64
# Gender     object
# dtype: object

# %%
id(df)
# Out:
# 2632798185712

# %%
df_fil_mean = df.copy()

# %%
id(df_fil_mean)
# Out:
# 2632799614048

# %%
df
# Out:
#       Name   Age  Height  Weight Gender
# 0    Alice  25.0   165.0    55.0      F
# 1      Bob  30.0   180.0    78.0      M
# 2  Charlie  35.0   175.0    72.0      M
# 3    David   NaN   170.0     NaN      M
# 4      Eva  40.0     NaN    68.0      F
# 5    Frank  28.0   178.0    80.0      M
# 6    Grace  33.0   160.0    54.0      F
# 7    Helen  29.0   158.0    50.0      F

# %% [markdown]
# ## Data Cleaning

# %%
#Using the mean to fill in the missing data in the column AGE
df_fil_mean["Age"] = df_fil_mean["Age"].fillna(df_fil_mean["Age"].mean())

# %%
df_fil_mean["Height"] = df_fil_mean["Height"].fillna(df_fil_mean["Height"].mean())
df_fil_mean["Weight"] = df_fil_mean["Weight"].fillna(df_fil_mean["Weight"].mean())

# %%
 df_medi = df.copy()

# %%
df_medi["Height"] = df_medi["Height"].fillna(df_medi["Height"].median())
df_medi["Weight"] = df_medi["Weight"].fillna(df_medi["Weight"].median())

# %%
df_medi["Age"] = df_medi["Age"].fillna(df_medi["Age"].median())

# %%
df_fil_mean.describe()
# Out:
#              Age      Height     Weight
# count   8.000000    8.000000   8.000000
# mean   31.428571  169.428571  65.285714
# std     4.624690    8.068584  11.322724
# min    25.000000  158.000000  50.000000
# 25%    28.750000  163.750000  54.750000
# 50%    30.714286  169.714286  66.642857
# 75%    33.500000  175.750000  73.500000
# max    40.000000  180.000000  80.000000

# %%
df_medi.describe()
# Out:
#              Age      Height     Weight
# count   8.000000    8.000000   8.000000
# mean   31.250000  169.500000  65.625000
# std     4.652188    8.071113  11.363318
# min    25.000000  158.000000  50.000000
# 25%    28.750000  163.750000  54.750000
# 50%    30.000000  170.000000  68.000000
# 75%    33.500000  175.750000  73.500000
# max    40.000000  180.000000  80.000000

# %%
# Handling missing values

# %%
df.fillna({"Age": df['Age'].mean()}, inplace=True) # inplace=ttrue replace the missing values with the mean directly without any further analysis

# %%
df.fillna({'Height':df['Height'].median()}, inplace=True) #this has to be used cos df was initially actioned

# %%
df.fillna({'Weight':df['Weight'].median()}, inplace=True)
# Check again
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    8 non-null      object
#  1   Age     8 non-null      float64
#  2   Height  8 non-null      float64
#  3   Weight  8 non-null      float64
#  4   Gender  8 non-null      object
# dtypes: float64(3), object(2)
# memory usage: 452.0+ bytes

# %%
adults = df[df['Age'] > 25]

# %%
adults
# Out:
#       Name        Age  Height  Weight Gender
# 1      Bob  30.000000   180.0    78.0      M
# 2  Charlie  35.000000   175.0    72.0      M
# 3    David  31.428571   170.0    68.0      M
# 4      Eva  40.000000   170.0    68.0      F
# 5    Frank  28.000000   178.0    80.0      M
# 6    Grace  33.000000   160.0    54.0      F
# 7    Helen  29.000000   158.0    50.0      F

# %% [markdown]
# ## Data Manipulation

# %%
# Select column

# %%
ages = df['Age']

# %%
# Filter rows
adults = df[df['Age'] > 18]

# %%
# Create new column BMI
df['BMI'] = df['Weight'] / (df['Height']/100)**2

# %%
# Sort by Age
df_sorted = df.sort_values('Age')

# %%
df_sorted
# Out:
#       Name        Age  Height  Weight Gender        BMI
# 0    Alice  25.000000   165.0    55.0      F  20.202020
# 5    Frank  28.000000   178.0    80.0      M  25.249337
# 7    Helen  29.000000   158.0    50.0      F  20.028842
# 1      Bob  30.000000   180.0    78.0      M  24.074074
# 3    David  31.428571   170.0    68.0      M  23.529412
# 6    Grace  33.000000   160.0    54.0      F  21.093750
# 2  Charlie  35.000000   175.0    72.0      M  23.510204
# 4      Eva  40.000000   170.0    68.0      F  23.529412

# %%
list (df["Gender"].unique())
# Out:
# ['F', 'M']

# %% [markdown]
# ## GroupBy & Aggregations

# %%
mean_age = df.groupby("Gender")["Age"].mean()
mean_age
# Out:
# Gender
# F    31.750000
# M    31.107143
# Name: Age, dtype: float64

# %%
agg_data = df.groupby("Gender").agg({
    "Age": "mean",
    "Weight": "sum",
    "BMI": "mean"
})

# %%
agg_data
# Out:
#               Age  Weight        BMI
# Gender
# F       31.750000   227.0  21.213506
# M       31.107143   298.0  24.090757

# %%
# Mean age by Gender
mean_age = df.groupby("Gender")["Age"].mean()

# Aggregation example
agg_data = df.groupby("Gender").agg({
    "Age": "mean",
    "Weight": "sum",
    "BMI": "mean"
})

mean_age, agg_data
# Out:
# (Gender
#  F    31.750000
#  M    31.107143
#  Name: Age, dtype: float64,
#                Age  Weight        BMI
#  Gender
#  F       31.750000   227.0  21.213506
#  M       31.107143   298.0  24.090757)

# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl.metadata (111 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
# Downloading matplotlib-3.10.6-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 230.3 kB/s eta 0:00:34
#    --- ------------------------------------ 0.8/8.1 MB 382.3 kB/s eta 0:00:20
#    ----- ---------------------------------- 1.0/8.1 MB 498.1 kB/s eta 0:00:15
#    ----- ---------------------------------- 1.0/8.1 MB 498.1 kB/s eta 0:00:15
#    ------ --------------------------------- 1.3/8.1 MB 521.5 kB/s eta 0:00:14
#    ------- -------------------------------- 1.6/8.1 MB 585.7 kB/s eta 0:00:12
#    --------- ------------------------------ 1.8/8.1 MB 633.9 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.1/8.1 MB 693.9 kB/s eta 0:00:09
#    ----------- ---------------------------- 2.4/8.1 MB 737.7 kB/s eta 0:00:08
#    ------------ --------------------------- 2.6/8.1 MB 773.2 kB/s eta 0:00:08
#    -------------- ------------------------- 2.9/8.1 MB 808.0 kB/s eta 0:00:07
#    --------------- ------------------------ 3.1/8.1 MB 825.2 kB/s eta 0:00:07
#    ---------------- ----------------------- 3.4/8.1 MB 847.4 kB/s eta 0:00:06
#    ---------------- ----------------------- 3.4/8.1 MB 847.4 kB/s eta 0:00:06
#    ------------------- -------------------- 3.9/8.1 MB 890.5 kB/s eta 0:00:05
#    -------------------- ------------------- 4.2/8.1 MB 907.9 kB/s eta 0:00:05
#    --------------------- ------------------ 4.5/8.1 MB 937.3 kB/s eta 0:00:04
#    ----------------------- ---------------- 4.7/8.1 MB 952.0 kB/s eta 0:00:04
#    ------------------------ --------------- 5.0/8.1 MB 974.1 kB/s eta 0:00:04
#    ------------------------- -------------- 5.2/8.1 MB 985.8 kB/s eta 0:00:03
#    --------------------------- ------------ 5.5/8.1 MB 1.0 MB/s eta 0:00:03
#    ----------------------------- ---------- 6.0/8.1 MB 1.0 MB/s eta 0:00:03
#    ------------------------------ --------- 6.3/8.1 MB 1.0 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.1 MB 1.0 MB/s eta 0:00:02
#    --------------------------------- ------ 6.8/8.1 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.1/8.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.1 MB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.1 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 7.9/8.1 MB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 1.1 MB/s  0:00:30
# Downloading contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.2-cp313-cp313-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.3 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.3 MB 1.3 MB/s eta 0:00:02
#    ------------- -------------------------- 0.8/2.3 MB 1.4 MB/s eta 0:00:02
#    ------------------ --------------------- 1.0/2.3 MB 1.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.3/2.3 MB 1.4 MB/s eta 0:00:01
#    --------------------------- ------------ 1.6/2.3 MB 1.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.8/2.3 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.1/2.3 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 1.3 MB/s  0:00:01
# Downloading kiwisolver-1.4.9-cp313-cp313-win_amd64.whl (73 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/7.0 MB 1.6 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.8/7.0 MB 1.3 MB/s eta 0:00:05
#    ------ --------------------------------- 1.0/7.0 MB 1.3 MB/s eta 0:00:05
#    ------- -------------------------------- 1.3/7.0 MB 1.3 MB/s eta 0:00:05
#    --------- ------------------------------ 1.6/7.0 MB 1.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 1.8/7.0 MB 1.2 MB/s eta 0:00:05
#    ------------ --------------------------- 2.1/7.0 MB 1.3 MB/s eta 0:00:04
#    ------------- -------------------------- 2.4/7.0 MB 1.2 MB/s eta 0:00:04
#    --------------- ------------------------ 2.6/7.0 MB 1.2 MB/s eta 0:00:04
#    ---------------- ----------------------- 2.9/7.0 MB 1.2 MB/s eta 0:00:04
#    ------------------ --------------------- 3.1/7.0 MB 1.2 MB/s eta 0:00:04
#    ------------------- -------------------- 3.4/7.0 MB 1.2 MB/s eta 0:00:03
#    --------------------- ------------------ 3.7/7.0 MB 1.2 MB/s eta 0:00:03
#    ---------------------- ----------------- 3.9/7.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------ --------------- 4.2/7.0 MB 1.2 MB/s eta 0:00:03
#    ------------------------- -------------- 4.5/7.0 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 4.7/7.0 MB 1.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------ --------- 5.2/7.0 MB 1.2 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.2 MB/s eta 0:00:02
#    --------------------------------- ------ 5.8/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 6.0/7.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------ --- 6.3/7.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.2 MB/s eta 0:00:01
#    ------------------------------------- -- 6.6/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------  6.8/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.2 MB/s  0:00:05
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----------- ---------------------------- 2/7 [kiwisolver]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ----------------- ---------------------- 3/7 [fonttools]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------- ----------- 5/7 [contourpy]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------- ----- 6/7 [matplotlib]
#    ---------------------------------------- 7/7 [matplotlib]
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.59.2 kiwisolver-1.4.9 matplotlib-3.10.6 pillow-11.3.0 pyparsing-3.2.3
# WARNING: Connection timed out while downloading.
# WARNING: Attempting to resume incomplete download (0 bytes/8.1 MB, attempt 1)

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Visualization with Matplotlib

# %%
plt.hist(df['Age'], bins=5, color='skyblue', edgecolor='black')
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.scatter(df['Age'], df["Weight"])
plt.title("Age Vs Weight")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.show()

# %%
plt.plot(df['Age'], df['Weight'])
plt.title("Age")
plt.xlabel("age")
plt.ylabel("Weight")
plt.show()

# %%
df.describe()
# Out:
#              Age      Height     Weight        BMI
# count   8.000000    8.000000   8.000000   8.000000
# mean   31.428571  169.500000  65.625000  22.652131
# std     4.624690    8.071113  11.363318   1.940404
# min    25.000000  158.000000  50.000000  20.028842
# 25%    28.750000  163.750000  54.750000  20.870818
# 50%    30.714286  170.000000  68.000000  23.519808
# 75%    33.500000  175.750000  73.500000  23.665577
# max    40.000000  180.000000  80.000000  25.249337

# %% [markdown]
# # Box Plot

# %%
plt.boxplot(df['Age'])
plt.title("Age box")
plt.ylabel("Age")
plt.show()

# %%
df
# Out:
#       Name        Age  Height  Weight Gender        BMI
# 0    Alice  25.000000   165.0    55.0      F  20.202020
# 1      Bob  30.000000   180.0    78.0      M  24.074074
# 2  Charlie  35.000000   175.0    72.0      M  23.510204
# 3    David  31.428571   170.0    68.0      M  23.529412
# 4      Eva  40.000000   170.0    68.0      F  23.529412
# 5    Frank  28.000000   178.0    80.0      M  25.249337
# 6    Grace  33.000000   160.0    54.0      F  21.093750
# 7    Helen  29.000000   158.0    50.0      F  20.028842

# %%
plt.boxplot([df['Age'].dropna(), df["Height"].dropna()],tick_labels= ['AGE', 'HEIGHT'])

plt.show()
#Using labels still works for now, but it will stop working in future versions (3.11+)

# %% [raw]
# Q1 , q2, q3

# %% [raw]
# QIR = q3- q1
# Q1 - 1.5QIR
# 1.5 QIR + Q3

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\olumi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %% [markdown]
# ## Visualization with Seaborn

# %%
sns.boxplot(x="Gender", y="BMI", data=df)
plt.title("BMI by Gender")
plt.show()

# %% [markdown]
# ## Example Workflow

# %%
# Load data
workflow_df = pd.read_csv("data.csv")

# Explore
print(workflow_df.head())
print(workflow_df.describe())

# Clean missing values
workflow_df.fillna(workflow_df.mean(numeric_only=True), inplace=True)

# GroupBy
print(workflow_df.groupby("Gender")["Age"].mean())

# Visualization
sns.histplot(workflow_df['Weight'], kde=True)
plt.title("Weight Distribution")
plt.show()
# Out:
#    Unnamed: 0     Name   Age  Height  Weight Gender
# 0           0    Alice  25.0   165.0    55.0      F
# 1           1      Bob  30.0   180.0    78.0      M
# 2           2  Charlie  35.0   175.0    72.0      M
# 3           3    David   NaN   170.0     NaN      M
# 4           4      Eva  40.0     NaN    68.0      F
#        Unnamed: 0        Age      Height     Weight
# count     8.00000   7.000000    7.000000   7.000000
# mean      3.50000  31.428571  169.428571  65.285714
# std       2.44949   4.995236    8.715066  12.229940
# min       0.00000  25.000000  158.000000  50.000000
# 25%       1.75000  28.500000  162.500000  54.500000
# 50%       3.50000  30.000000  170.000000  68.000000
# 75%       5.25000  34.000000  176.500000  75.000000
# max       7.00000  40.000000  180.000000  80.000000
# Gender
# F    31.750000
# M    31.107143
# Name: Age, dtype: float64

# %% [markdown]
# ## Summary
# - **Pandas** is essential for data manipulation.
# - **Matplotlib** & **Seaborn** are useful for visualization.
# - **GroupBy** is powerful for aggregations.
# - **Data cleaning** ensures dataset quality.
# - Combined workflow integrates all steps for real projects.
