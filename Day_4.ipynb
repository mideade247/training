# %% [markdown]
# 1.   Data Loading
# 2.   Data Cleaning
# 3.   Data Manipulation
# 4.   Data Visualization

# %%
import pandas as pd

# %% [markdown]
# # 1.Load Data

# %%
df = pd.read_csv(r"C:\Users\olumi\Desktop\Training\amazon.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df = pd.read_csv(r"C:\Users\olumi\Desktop\Training\amazon.csv")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 340

# %%
df.head()
# Out:
#    Unnamed: 0     Name   Age  Height  Weight Gender
# 0           0    Alice  25.0   165.0    55.0      F
# 1           1      Bob  30.0   180.0    78.0      M
# 2           2  Charlie  35.0   175.0    72.0      M
# 3           3    David   NaN   170.0     NaN      M
# 4           4      Eva  40.0     NaN    68.0      F

# %%
len(df)
# Out:
# 1465

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: object(16)
# memory usage: 183.2+ KB

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B08WRWPM22  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# top            ₹999                 50%    4.1        9,378
# freq            120                  56    244            9
#
#                                             about_product  \
# count                                                1465
# unique                                               1293
# top     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# freq                                                    6
#
#                                                   user_id  \
# count                                                1465
# unique                                               1194
# top     AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# freq                                                   10
#
#                                                 user_name  \
# count                                                1465
# unique                                               1194
# top     $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger P...
# freq                                                   10
#
#                                                 review_id  \
# count                                                1465
# unique                                               1194
# top     R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,R...
# freq                                                   10
#
#                                              review_title  \
# count                                                1465
# unique                                               1194
# top     Worked on iPhone 7 and didn’t work on XR,Good ...
# freq                                                   10
#
#                                            review_content  \
# count                                                1465
# unique                                               1212
# top     I am not big on camera usage, personally. I wa...
# freq                                                    8
#
#                                                  img_link  \
# count                                                1465
# unique                                               1412
# top     https://m.media-amazon.com/images/I/413sCRKobN...
# freq                                                    3
#
#                                              product_link
# count                                                1465
# unique                                               1465
# top     https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# freq                                                    1

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B08WRWPM22  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# top            ₹999                 50%    4.1        9,378
# freq            120                  56    244            9
#
#                                             about_product  \
# count                                                1465
# unique                                               1293
# top     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# freq                                                    6
#
#                                                   user_id  \
# count                                                1465
# unique                                               1194
# top     AHIKJUDTVJ4T6DV6IUGFYZ5LXMPA,AE55KTFVNXYFD5FPY...
# freq                                                   10
#
#                                                 user_name  \
# count                                                1465
# unique                                               1194
# top     $@|\|TO$|-|,Sethu madhav,Akash Thakur,Burger P...
# freq                                                   10
#
#                                                 review_id  \
# count                                                1465
# unique                                               1194
# top     R3F4T5TRYPTMIG,R3DQIEC603E7AY,R1O4Z15FD40PV5,R...
# freq                                                   10
#
#                                              review_title  \
# count                                                1465
# unique                                               1194
# top     Worked on iPhone 7 and didn’t work on XR,Good ...
# freq                                                   10
#
#                                            review_content  \
# count                                                1465
# unique                                               1212
# top     I am not big on camera usage, personally. I wa...
# freq                                                    8
#
#                                                  img_link  \
# count                                                1465
# unique                                               1412
# top     https://m.media-amazon.com/images/I/413sCRKobN...
# freq                                                    3
#
#                                              product_link
# count                                                1465
# unique                                               1465
# top     https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
# freq                                                    1

# %% [markdown]
# #2. Data Cleaning

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# rating_count           2
# product_id             0
# category               0
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
round(df.isnull().sum() / len(df) * 100, 2).sort_values(ascending=False)
# Out:
# rating_count           0.14
# product_id             0.00
# category               0.00
# product_name           0.00
# discounted_price       0.00
# actual_price           0.00
# discount_percentage    0.00
# rating                 0.00
# about_product          0.00
# user_id                0.00
# user_name              0.00
# review_id              0.00
# review_title           0.00
# review_content         0.00
# img_link               0.00
# product_link           0.00
# dtype: float64

# %%
import copy

# %%
A = 6

# %%
b = copy.copy(A)

# %%
c = copy.deepcopy(A)

# %%
id(b)
# Out:
# 1802242883984

# %%
id(A)
# Out:
# 1802242883984

# %%
id(c)
# Out:
# 1802242883984

# %%
b = 9

# %%
A
# Out:
# 6

# %%
df.isnull().sum().sum()
# Out:
# np.int64(2)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2     Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3     Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4     Computers&Accessories|Accessories&Peripherals|...             ₹154
# ...                                                 ...              ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             ₹379
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,280
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 0          ₹1,099                 64%    4.2       24,269
# 1            ₹349                 43%    4.0       43,994
# 2          ₹1,899                 90%    3.9        7,928
# 3            ₹699                 53%    4.2       94,363
# 4            ₹399                 61%    4.2       16,905
# ...           ...                 ...    ...          ...
# 1460         ₹919                 59%      4        1,090
# 1461       ₹3,045                 25%    4.1        4,118
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %% [markdown]
# ### Changing Data Type

# %%
# Changing the data type of discounted price  actual price and discount_percentage

df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')

df['discount_percentage'] = df['discount_percentage'].str.replace('%', '', regex=False)
df['discount_percentage'] = df['discount_percentage'].astype(float)

df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: float64(3), object(13)
# memory usage: 183.2+ KB

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# 1     Computers&Accessories|Accessories&Peripherals|...             199.0
# 2     Computers&Accessories|Accessories&Peripherals|...             199.0
# 3     Computers&Accessories|Accessories&Peripherals|...             329.0
# 4     Computers&Accessories|Accessories&Peripherals|...             154.0
# ...                                                 ...               ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             379.0
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2280.0
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...            1399.0
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2863.0
#
#       actual_price  discount_percentage rating rating_count  \
# 0           1099.0                 64.0    4.2       24,269
# 1            349.0                 43.0    4.0       43,994
# 2           1899.0                 90.0    3.9        7,928
# 3            699.0                 53.0    4.2       94,363
# 4            399.0                 61.0    4.2       16,905
# ...            ...                  ...    ...          ...
# 1460         919.0                 59.0      4        1,090
# 1461        3045.0                 25.0    4.1        4,118
# 1462        3080.0                 28.0    3.6          468
# 1463        1890.0                 26.0      4        8,031
# 1464        3690.0                 22.0    4.3        6,987
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %%
df["rating"].unique()
# Out:
# array(['4.2', '4.0', '3.9', '4.1', '4.3', '4.4', '4.5', '3.7', '3.3',
#        '3.6', '3.4', '3.8', '3.5', '4.6', '3.2', '5.0', '4.7', '3.0',
#        '2.8', '4', '3.1', '4.8', '2.3', '|', '2', '3', '2.6', '2.9'],
#       dtype=object)

# %%
# Changing Rating Columns Data Type

df['rating'] = df['rating'].str.replace('|', '2.5').astype('float64')

# %%
# Changing 'rating_count' Column Data Type and replacing comma with space

df['rating_count'] = df['rating_count'].str.replace(',', '').astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1465 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
#  15  product_link         1465 non-null   object
# dtypes: float64(5), object(11)
# memory usage: 183.2+ KB

# %%
df.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1465.000000    1465.000000          1465.000000  1465.000000
# mean        3125.310874    5444.990635            47.691468     4.095495
# std         6944.304394   10874.826864            21.635905     0.294543
# min           39.000000      39.000000             0.000000     2.000000
# 25%          325.000000     800.000000            32.000000     4.000000
# 50%          799.000000    1650.000000            50.000000     4.100000
# 75%         1999.000000    4295.000000            63.000000     4.300000
# max        77990.000000  139900.000000            94.000000     5.000000
#
#         rating_count
# count    1463.000000
# mean    18295.541353
# std     42753.864952
# min         2.000000
# 25%      1186.000000
# 50%      5179.000000
# 75%     17336.500000
# max    426973.000000

# %% [markdown]
# ### Checking the Missing Values

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# rating_count           2
# product_id             0
# category               0
# product_name           0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Find missing values percentage in the data
round(df.isnull().sum() / len(df) * 100, 2).sort_values(ascending=False)
# Out:
# rating_count           0.14
# product_id             0.00
# category               0.00
# product_name           0.00
# discounted_price       0.00
# actual_price           0.00
# discount_percentage    0.00
# rating                 0.00
# about_product          0.00
# user_id                0.00
# user_name              0.00
# review_id              0.00
# review_title           0.00
# review_content         0.00
# img_link               0.00
# product_link           0.00
# dtype: float64

# %%
# Find Duplicate
df.duplicated().any()
# Out:
# np.False_

# %% [markdown]
# # Data Manipulation

# %% [markdown]
# ### Indexing

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             399.0
# 1     Computers&Accessories|Accessories&Peripherals|...             199.0
# 2     Computers&Accessories|Accessories&Peripherals|...             199.0
# 3     Computers&Accessories|Accessories&Peripherals|...             329.0
# 4     Computers&Accessories|Accessories&Peripherals|...             154.0
# ...                                                 ...               ...
# 1460  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...             379.0
# 1461  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2280.0
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...            2219.0
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...            1399.0
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2863.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 0           1099.0                 64.0     4.2       24269.0
# 1            349.0                 43.0     4.0       43994.0
# 2           1899.0                 90.0     3.9        7928.0
# 3            699.0                 53.0     4.2       94363.0
# 4            399.0                 61.0     4.2       16905.0
# ...            ...                  ...     ...           ...
# 1460         919.0                 59.0     4.0        1090.0
# 1461        3045.0                 25.0     4.1        4118.0
# 1462        3080.0                 28.0     3.6         468.0
# 1463        1890.0                 26.0     4.0        8031.0
# 1464        3690.0                 22.0     4.3        6987.0
#
#                                           about_product  \
# 0     High Compatibility : Compatible With iPhone 12...
# 1     Compatible with all Type C enabled devices, be...
# 2     【 Fast Charger& Data Sync】-With built-in safet...
# 3     The boAt Deuce USB 300 2 in 1 cable is compati...
# 4     [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                                                 ...
# 1460  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# 1461                       230 Volts, 400 watts, 1 Year
# 1462  International design and styling|Two heat sett...
# 1463  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 0     AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1     AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2     AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3     AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4     AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                 ...
# 1460  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# 1461  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# 1462  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# 1463  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 0     Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1     ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2     Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3     Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4     rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                 ...
# 1460  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# 1461  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# 1462  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# 1463  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 0     R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1     RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2     R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3     R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4     R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                 ...
# 1460  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# 1461  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# 1462  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# 1463  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# 0     Satisfied,Charging is really fast,Value for mo...
# 1     A Good Braided Cable for Your Type C Device,Go...
# 2     Good speed for earlier versions,Good Product,W...
# 3     Good product,Good one,Nice,Really nice product...
# 4     As good as original,Decent,Good one for second...
# ...                                                 ...
# 1460  Received the product without spanner,Excellent...
# 1461  ok,everything was good couldn't return bcoz I ...
# 1462  very good,Work but front melt after 2 month,Go...
# 1463  Fan Speed is slow,Good quality,Good product,go...
# 1464  Works perfect,Ok good product,Nice Product. Re...
#
#                                          review_content  \
# 0     Looks durable Charging is fine tooNo complains...
# 1     I ordered this cable to connect my phone to An...
# 2     Not quite durable and sturdy,https://m.media-a...
# 3     Good product,long wire,Charges good,Nice,I bou...
# 4     Bought this instead of original apple, does th...
# ...                                                 ...
# 1460  I received product without spanner,Excellent p...
# 1461  ok,got everything as mentioned but the measuri...
# 1462  plastic but cool body ,u have to find sturdy s...
# 1463  I have installed this in my kitchen working fi...
# 1464  It does it job perfectly..only issue is temp c...
#
#                                                img_link  \
# 0     https://m.media-amazon.com/images/W/WEBP_40237...
# 1     https://m.media-amazon.com/images/W/WEBP_40237...
# 2     https://m.media-amazon.com/images/W/WEBP_40237...
# 3     https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4     https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                 ...
# 1460  https://m.media-amazon.com/images/I/41fDdRtjfx...
# 1461  https://m.media-amazon.com/images/I/41gzDxk4+k...
# 1462  https://m.media-amazon.com/images/W/WEBP_40237...
# 1463  https://m.media-amazon.com/images/W/WEBP_40237...
# 1464  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 0     https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1     https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2     https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3     https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4     https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                 ...
# 1460  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# 1461  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# 1462  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# 1463  https://www.amazon.in/Havells-Ventilair-230mm-...
# 1464  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 16 columns]

# %%
# Set product_id as index
df.set_index("product_id", inplace=True)

# %%
df
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                       ...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B096MSW6CT  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
# ...                                                       ...
# B08L7J3T31  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# B01M6453MB  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B009P2LIL4  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# B00J5DYCCA  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# B01486F4G6  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 64.0     4.2
# B098NS6PVG             199.0         349.0                 43.0     4.0
# B096MSW6CT             199.0        1899.0                 90.0     3.9
# B08HDJ86NZ             329.0         699.0                 53.0     4.2
# B08CF3B7N1             154.0         399.0                 61.0     4.2
# ...                      ...           ...                  ...     ...
# B08L7J3T31             379.0         919.0                 59.0     4.0
# B01M6453MB            2280.0        3045.0                 25.0     4.1
# B009P2LIL4            2219.0        3080.0                 28.0     3.6
# B00J5DYCCA            1399.0        1890.0                 26.0     4.0
# B01486F4G6            2863.0        3690.0                 22.0     4.3
#
#             rating_count                                      about_product  \
# product_id
# B07JW9H4J1       24269.0  High Compatibility : Compatible With iPhone 12...
# B098NS6PVG       43994.0  Compatible with all Type C enabled devices, be...
# B096MSW6CT        7928.0  【 Fast Charger& Data Sync】-With built-in safet...
# B08HDJ86NZ       94363.0  The boAt Deuce USB 300 2 in 1 cable is compati...
# B08CF3B7N1       16905.0  [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                  ...                                                ...
# B08L7J3T31        1090.0  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# B01M6453MB        4118.0                       230 Volts, 400 watts, 1 Year
# B009P2LIL4         468.0  International design and styling|Two heat sett...
# B00J5DYCCA        8031.0  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# B01486F4G6        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                       user_id  \
# product_id
# B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                       ...
# B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                                     user_name  \
# product_id
# B07JW9H4J1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# B098NS6PVG  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# B096MSW6CT  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# B08HDJ86NZ  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# B08CF3B7N1  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                       ...
# B08L7J3T31  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# B01M6453MB  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# B009P2LIL4  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# B00J5DYCCA  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# B01486F4G6  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                                     review_id  \
# product_id
# B07JW9H4J1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# B098NS6PVG  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# B096MSW6CT  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# B08HDJ86NZ  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# B08CF3B7N1  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                       ...
# B08L7J3T31  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# B01M6453MB  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# B009P2LIL4  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# B00J5DYCCA  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# B01486F4G6  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                                  review_title  \
# product_id
# B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# B096MSW6CT  Good speed for earlier versions,Good Product,W...
# B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# B08CF3B7N1  As good as original,Decent,Good one for second...
# ...                                                       ...
# B08L7J3T31  Received the product without spanner,Excellent...
# B01M6453MB  ok,everything was good couldn't return bcoz I ...
# B009P2LIL4  very good,Work but front melt after 2 month,Go...
# B00J5DYCCA  Fan Speed is slow,Good quality,Good product,go...
# B01486F4G6  Works perfect,Ok good product,Nice Product. Re...
#
#                                                review_content  \
# product_id
# B07JW9H4J1  Looks durable Charging is fine tooNo complains...
# B098NS6PVG  I ordered this cable to connect my phone to An...
# B096MSW6CT  Not quite durable and sturdy,https://m.media-a...
# B08HDJ86NZ  Good product,long wire,Charges good,Nice,I bou...
# B08CF3B7N1  Bought this instead of original apple, does th...
# ...                                                       ...
# B08L7J3T31  I received product without spanner,Excellent p...
# B01M6453MB  ok,got everything as mentioned but the measuri...
# B009P2LIL4  plastic but cool body ,u have to find sturdy s...
# B00J5DYCCA  I have installed this in my kitchen working fi...
# B01486F4G6  It does it job perfectly..only issue is temp c...
#
#                                                      img_link  \
# product_id
# B07JW9H4J1  https://m.media-amazon.com/images/W/WEBP_40237...
# B098NS6PVG  https://m.media-amazon.com/images/W/WEBP_40237...
# B096MSW6CT  https://m.media-amazon.com/images/W/WEBP_40237...
# B08HDJ86NZ  https://m.media-amazon.com/images/I/41V5FtEWPk...
# B08CF3B7N1  https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                       ...
# B08L7J3T31  https://m.media-amazon.com/images/I/41fDdRtjfx...
# B01M6453MB  https://m.media-amazon.com/images/I/41gzDxk4+k...
# B009P2LIL4  https://m.media-amazon.com/images/W/WEBP_40237...
# B00J5DYCCA  https://m.media-amazon.com/images/W/WEBP_40237...
# B01486F4G6  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                                  product_link
# product_id
# B07JW9H4J1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# B098NS6PVG  https://www.amazon.in/Ambrane-Unbreakable-Char...
# B096MSW6CT  https://www.amazon.in/Sounce-iPhone-Charging-C...
# B08HDJ86NZ  https://www.amazon.in/Deuce-300-Resistant-Tang...
# B08CF3B7N1  https://www.amazon.in/Portronics-Konnect-POR-1...
# ...                                                       ...
# B08L7J3T31  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# B01M6453MB  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# B009P2LIL4  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...
# B00J5DYCCA  https://www.amazon.in/Havells-Ventilair-230mm-...
# B01486F4G6  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1465 rows x 15 columns]

# %% [markdown]
# ### filtering the colunm

# %%
# Products with rating >= 4
high_rated = df[df["rating"] >= 4]

# %%
high_rated
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# ...                                                       ...
# B00TI8E7BI  Philips HD9306/06 1.5-Litre Electric Kettle (M...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
# B08WRWPM22  Computers&Accessories|Accessories&Peripherals|...
# ...                                                       ...
# B00TI8E7BI  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B08L7J3T31  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# B01M6453MB  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B00J5DYCCA  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# B01486F4G6  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1            399.00        1099.0                 64.0     4.2
# B098NS6PVG            199.00         349.0                 43.0     4.0
# B08HDJ86NZ            329.00         699.0                 53.0     4.2
# B08CF3B7N1            154.00         399.0                 61.0     4.2
# B08WRWPM22            176.63         499.0                 65.0     4.1
# ...                      ...           ...                  ...     ...
# B00TI8E7BI           2695.00        2695.0                  0.0     4.4
# B08L7J3T31            379.00         919.0                 59.0     4.0
# B01M6453MB           2280.00        3045.0                 25.0     4.1
# B00J5DYCCA           1399.00        1890.0                 26.0     4.0
# B01486F4G6           2863.00        3690.0                 22.0     4.3
#
#             rating_count                                      about_product  \
# product_id
# B07JW9H4J1       24269.0  High Compatibility : Compatible With iPhone 12...
# B098NS6PVG       43994.0  Compatible with all Type C enabled devices, be...
# B08HDJ86NZ       94363.0  The boAt Deuce USB 300 2 in 1 cable is compati...
# B08CF3B7N1       16905.0  [CHARGE & SYNC FUNCTION]- This cable comes wit...
# B08WRWPM22       15188.0  It Ensures High Speed Transmission And Chargin...
# ...                  ...                                                ...
# B00TI8E7BI        2518.0  Food grade stainless steel, Frequency: 50 Hz. ...
# B08L7J3T31        1090.0  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# B01M6453MB        4118.0                       230 Volts, 400 watts, 1 Year
# B00J5DYCCA        8031.0  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# B01486F4G6        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                       user_id  \
# product_id
# B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# B08WRWPM22  AG7C6DAADCTRQJG2BRS3RIKDT52Q,AFU7BOMPVJ7Q3TTA4...
# ...                                                       ...
# B00TI8E7BI  AHYXOMUJUKZHBWHP43ZAB265EDGA,AG4C27NTZZ7HTG6W3...
# B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                                     user_name  \
# product_id
# B07JW9H4J1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# B098NS6PVG  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# B08HDJ86NZ  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# B08CF3B7N1  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# B08WRWPM22  Vivek kumar,Amazon Customer,SARTHAK,Chiranjeev...
# ...                                                       ...
# B00TI8E7BI  AmazonCust,DD_Zen,Amazon Customer,VINISH THOMA...
# B08L7J3T31  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# B01M6453MB  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# B00J5DYCCA  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# B01486F4G6  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                                     review_id  \
# product_id
# B07JW9H4J1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# B098NS6PVG  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# B08HDJ86NZ  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# B08CF3B7N1  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# B08WRWPM22  R8E73K2KWJRDS,RSD0JTIIWQQL8,R64CRSTE9SLW1,R2FR...
# ...                                                       ...
# B00TI8E7BI  R252H4TFMWK9L7,R3SAFGRVGD7GTV,R1FVCFYT4SGY76,R...
# B08L7J3T31  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# B01M6453MB  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# B00J5DYCCA  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# B01486F4G6  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                                  review_title  \
# product_id
# B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# B08CF3B7N1  As good as original,Decent,Good one for second...
# B08WRWPM22  Long durable.,good,Does not charge Lenovo m8 t...
# ...                                                       ...
# B00TI8E7BI  3,Sturdy and Works Flawlessly,Excellent 👍,Real...
# B08L7J3T31  Received the product without spanner,Excellent...
# B01M6453MB  ok,everything was good couldn't return bcoz I ...
# B00J5DYCCA  Fan Speed is slow,Good quality,Good product,go...
# B01486F4G6  Works perfect,Ok good product,Nice Product. Re...
#
#                                                review_content  \
# product_id
# B07JW9H4J1  Looks durable Charging is fine tooNo complains...
# B098NS6PVG  I ordered this cable to connect my phone to An...
# B08HDJ86NZ  Good product,long wire,Charges good,Nice,I bou...
# B08CF3B7N1  Bought this instead of original apple, does th...
# B08WRWPM22  Build quality is good and it is comes with 2 y...
# ...                                                       ...
# B00TI8E7BI  Cord is small and sound while heating,Well bui...
# B08L7J3T31  I received product without spanner,Excellent p...
# B01M6453MB  ok,got everything as mentioned but the measuri...
# B00J5DYCCA  I have installed this in my kitchen working fi...
# B01486F4G6  It does it job perfectly..only issue is temp c...
#
#                                                      img_link  \
# product_id
# B07JW9H4J1  https://m.media-amazon.com/images/W/WEBP_40237...
# B098NS6PVG  https://m.media-amazon.com/images/W/WEBP_40237...
# B08HDJ86NZ  https://m.media-amazon.com/images/I/41V5FtEWPk...
# B08CF3B7N1  https://m.media-amazon.com/images/W/WEBP_40237...
# B08WRWPM22  https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                       ...
# B00TI8E7BI  https://m.media-amazon.com/images/I/41JyZuDzDg...
# B08L7J3T31  https://m.media-amazon.com/images/I/41fDdRtjfx...
# B01M6453MB  https://m.media-amazon.com/images/I/41gzDxk4+k...
# B00J5DYCCA  https://m.media-amazon.com/images/W/WEBP_40237...
# B01486F4G6  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                                  product_link
# product_id
# B07JW9H4J1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# B098NS6PVG  https://www.amazon.in/Ambrane-Unbreakable-Char...
# B08HDJ86NZ  https://www.amazon.in/Deuce-300-Resistant-Tang...
# B08CF3B7N1  https://www.amazon.in/Portronics-Konnect-POR-1...
# B08WRWPM22  https://www.amazon.in/boAt-Micro-USB-Tangle-Fr...
# ...                                                       ...
# B00TI8E7BI  https://www.amazon.in/Philips-HD9306-06-1-5-Li...
# B08L7J3T31  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...
# B01M6453MB  https://www.amazon.in/Prestige-Delight-PRWO-1-...
# B00J5DYCCA  https://www.amazon.in/Havells-Ventilair-230mm-...
# B01486F4G6  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...
#
# [1110 rows x 15 columns]

# %% [markdown]
# ### Creating New Colunm

# %%
# Calculate savings (actual - discounted)
df["savings"] = df["actual_price"] - df["discounted_price"]

# %%
df
# Out:
#                                                  product_name  \
# product_id
# B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...                                                       ...
# B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                      category  \
# product_id
# B07JW9H4J1  Computers&Accessories|Accessories&Peripherals|...
# B098NS6PVG  Computers&Accessories|Accessories&Peripherals|...
# B096MSW6CT  Computers&Accessories|Accessories&Peripherals|...
# B08HDJ86NZ  Computers&Accessories|Accessories&Peripherals|...
# B08CF3B7N1  Computers&Accessories|Accessories&Peripherals|...
# ...                                                       ...
# B08L7J3T31  Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# B01M6453MB  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# B009P2LIL4  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# B00J5DYCCA  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# B01486F4G6  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
#
#             discounted_price  actual_price  discount_percentage  rating  \
# product_id
# B07JW9H4J1             399.0        1099.0                 64.0     4.2
# B098NS6PVG             199.0         349.0                 43.0     4.0
# B096MSW6CT             199.0        1899.0                 90.0     3.9
# B08HDJ86NZ             329.0         699.0                 53.0     4.2
# B08CF3B7N1             154.0         399.0                 61.0     4.2
# ...                      ...           ...                  ...     ...
# B08L7J3T31             379.0         919.0                 59.0     4.0
# B01M6453MB            2280.0        3045.0                 25.0     4.1
# B009P2LIL4            2219.0        3080.0                 28.0     3.6
# B00J5DYCCA            1399.0        1890.0                 26.0     4.0
# B01486F4G6            2863.0        3690.0                 22.0     4.3
#
#             rating_count                                      about_product  \
# product_id
# B07JW9H4J1       24269.0  High Compatibility : Compatible With iPhone 12...
# B098NS6PVG       43994.0  Compatible with all Type C enabled devices, be...
# B096MSW6CT        7928.0  【 Fast Charger& Data Sync】-With built-in safet...
# B08HDJ86NZ       94363.0  The boAt Deuce USB 300 2 in 1 cable is compati...
# B08CF3B7N1       16905.0  [CHARGE & SYNC FUNCTION]- This cable comes wit...
# ...                  ...                                                ...
# B08L7J3T31        1090.0  SUPREME QUALITY 90 GRAM 3 LAYER THIK PP SPUN F...
# B01M6453MB        4118.0                       230 Volts, 400 watts, 1 Year
# B009P2LIL4         468.0  International design and styling|Two heat sett...
# B00J5DYCCA        8031.0  Fan sweep area: 230 MM ; Noise level: (40 - 45...
# B01486F4G6        6987.0  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                       user_id  \
# product_id
# B07JW9H4J1  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# B098NS6PVG  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# B096MSW6CT  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# B08HDJ86NZ  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# B08CF3B7N1  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
# ...                                                       ...
# B08L7J3T31  AHITFY6AHALOFOHOZEOC6XBP4FEA,AFRABBODZJZQB6Z4U...
# B01M6453MB  AFG5FM3NEMOL6BNFRV2NK5FNJCHQ,AGEINTRN6Z563RMLH...
# B009P2LIL4  AGVPWCMAHYQWJOQKMUJN4DW3KM5Q,AF4Q3E66MY4SR7YQZ...
# B00J5DYCCA  AF2JQCLSCY3QJATWUNNHUSVUPNQQ,AFDMLUXC5LS5RXDJS...
# B01486F4G6  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                                     user_name  \
# product_id
# B07JW9H4J1  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# B098NS6PVG  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# B096MSW6CT  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# B08HDJ86NZ  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# B08CF3B7N1  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
# ...                                                       ...
# B08L7J3T31  Prabha ds,Raghuram bk,Real Deal,Amazon Custome...
# B01M6453MB  Manu Bhai,Naveenpittu,Evatira Sangma,JAGANNADH...
# B009P2LIL4  Nehal Desai,Danish Parwez,Amazon Customer,Amaz...
# B00J5DYCCA  Shubham Dubey,E.GURUBARAN,Mayank S.,eusuf khan...
# B01486F4G6  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                                     review_id  \
# product_id
# B07JW9H4J1  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# B098NS6PVG  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# B096MSW6CT  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# B08HDJ86NZ  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# B08CF3B7N1  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
# ...                                                       ...
# B08L7J3T31  R3G3XFHPBFF0E8,R3C0BZCD32EIGW,R2EBVBCN9QPD9R,R...
# B01M6453MB  R3DDL2UPKQ2CK9,R2SYYU1OATVIU5,R1VM993161IYRW,R...
# B009P2LIL4  R1TLRJVW4STY5I,R2O455KRN493R1,R3Q5MVGBRIAS2G,R...
# B00J5DYCCA  R39Q2Y79MM9SWK,R3079BG1NIH6MB,R29A31ZELTZNJM,R...
# B01486F4G6  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                                  review_title  \
# product_id
# B07JW9H4J1  Satisfied,Charging is really fast,Value for mo...
# B098NS6PVG  A Good Braided Cable for Your Type C Device,Go...
# B096MSW6CT  Good speed for earlier versions,Good Product,W...
# B08HDJ86NZ  Good product,Good one,Nice,Really nice product...
# B08CF3B7N1  As good as original,Decent,Good one for second...
# ...                                                       ...
# B08L7J3T31  Received the product without spanner,Excellent...
# B01M6453MB  ok,everything was good couldn't return bcoz I ...
# B009P2LIL4  very good,Work but front melt after 2 month,Go...
# B00J5DYCCA  Fan Speed is slow,Good quality,Good product,go...
# B01486F4G6  Works perfect,Ok good product,Nice Product. Re...
#
#                                                review_content  \
# product_id
# B07JW9H4J1  Looks durable Charging is fine tooNo complains...
# B098NS6PVG  I ordered this cable to connect my phone to An...
# B096MSW6CT  Not quite durable and sturdy,https://m.media-a...
# B08HDJ86NZ  Good product,long wire,Charges good,Nice,I bou...
# B08CF3B7N1  Bought this instead of original apple, does th...
# ...                                                       ...
# B08L7J3T31  I received product without spanner,Excellent p...
# B01M6453MB  ok,got everything as mentioned but the measuri...
# B009P2LIL4  plastic but cool body ,u have to find sturdy s...
# B00J5DYCCA  I have installed this in my kitchen working fi...
# B01486F4G6  It does it job perfectly..only issue is temp c...
#
#                                                      img_link  \
# product_id
# B07JW9H4J1  https://m.media-amazon.com/images/W/WEBP_40237...
# B098NS6PVG  https://m.media-amazon.com/images/W/WEBP_40237...
# B096MSW6CT  https://m.media-amazon.com/images/W/WEBP_40237...
# B08HDJ86NZ  https://m.media-amazon.com/images/I/41V5FtEWPk...
# B08CF3B7N1  https://m.media-amazon.com/images/W/WEBP_40237...
# ...                                                       ...
# B08L7J3T31  https://m.media-amazon.com/images/I/41fDdRtjfx...
# B01M6453MB  https://m.media-amazon.com/images/I/41gzDxk4+k...
# B009P2LIL4  https://m.media-amazon.com/images/W/WEBP_40237...
# B00J5DYCCA  https://m.media-amazon.com/images/W/WEBP_40237...
# B01486F4G6  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                                  product_link  savings
# product_id
# B07JW9H4J1  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...    700.0
# B098NS6PVG  https://www.amazon.in/Ambrane-Unbreakable-Char...    150.0
# B096MSW6CT  https://www.amazon.in/Sounce-iPhone-Charging-C...   1700.0
# B08HDJ86NZ  https://www.amazon.in/Deuce-300-Resistant-Tang...    370.0
# B08CF3B7N1  https://www.amazon.in/Portronics-Konnect-POR-1...    245.0
# ...                                                       ...      ...
# B08L7J3T31  https://www.amazon.in/Noir-Aqua-Spanner-Purifi...    540.0
# B01M6453MB  https://www.amazon.in/Prestige-Delight-PRWO-1-...    765.0
# B009P2LIL4  https://www.amazon.in/Bajaj-RX-10-2000-Watt-Co...    861.0
# B00J5DYCCA  https://www.amazon.in/Havells-Ventilair-230mm-...    491.0
# B01486F4G6  https://www.amazon.in/Borosil-Jumbo-1000-Watt-...    827.0
#
# [1465 rows x 16 columns]

# %% [markdown]
# ### Sorting the colunm

# %%
# Sort by discount
df_sorted = df.sort_values(by="discount_percentage", ascending=False)

# Sort by rating
df_sorted = df.sort_values(by="rating", ascending=False)

# %% [markdown]
# ### Group By and Aggregations

# %%
# Average rating per category
avg_rating = df.groupby("category")["rating"].mean()
avg_rating
# Out:
# category
# Car&Motorbike|CarAccessories|InteriorAccessories|AirPurifiers&Ionizers                                                    3.800000
# Computers&Accessories|Accessories&Peripherals|Adapters|USBtoUSBAdapters                                                   4.150000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCHeadsets                                           3.500000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCMicrophones                                        3.600000
# Computers&Accessories|Accessories&Peripherals|Audio&VideoAccessories|PCSpeakers                                           4.050000
#                                                                                                                             ...
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|GelInkRollerballPens        4.250000
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|LiquidInkRollerballPens     4.150000
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|RetractableBallpointPens    4.300000
# OfficeProducts|OfficePaperProducts|Paper|Stationery|Pens,Pencils&WritingSupplies|Pens&Refills|StickBallpointPens          4.133333
# Toys&Games|Arts&Crafts|Drawing&PaintingSupplies|ColouringPens&Markers                                                     4.300000
# Name: rating, Length: 211, dtype: float64

# %% [markdown]
# # Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Line Plot

# %%
# Sort by price so line looks meaningful
df_sorted = df.sort_values("actual_price")

plt.figure(figsize=(10,6))
plt.plot(df_sorted['actual_price'], df_sorted['rating'], color="blue", marker="o", linestyle="-")
plt.xlabel("Actual Price")
plt.ylabel("Rating")
plt.title("Line Plot: Actual Price vs Rating")
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
avg_rating = df.groupby("category")[["actual_price","rating"]].mean()
avg_rating_f = avg_rating.head() 

plt.figure(figsize=(12,6))
plt.bar(avg_rating.index, avg_rating['rating'], color="orange")
plt.xticks(rotation=45)
plt.ylabel("Average Rating")
plt.title("Bar Plot: Average Rating per Category")
plt.show()

# %% [markdown]
# ### Histogrm

# %%
# Plot distribution of actual_price
plt.hist(df['actual_price'])
plt.xlabel('Actual Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
# Plot actual_price vs. rating
plt.scatter(df['actual_price'], df['rating'])
plt.xlabel('Actual_price')
plt.ylabel('Rating')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# label encode categorical variables

le_category = LabelEncoder()
le_review_id = LabelEncoder()
le_review_content = LabelEncoder()
le_product_name = LabelEncoder()
le_user_name = LabelEncoder()
le_about_product = LabelEncoder()
le_user_id = LabelEncoder()
le_review_title = LabelEncoder()
le_img_link = LabelEncoder()
le_product_link = LabelEncoder()


df['category'] = le_category.fit_transform(df['category'])
df['review_id'] = le_review_id.fit_transform(df['review_id'])
df['review_content'] = le_review_content.fit_transform(df['review_content'])
df['product_name'] = le_product_name.fit_transform(df['product_name'])
df['user_name'] = le_user_name.fit_transform(df['user_name'])
df['about_product'] = le_about_product.fit_transform(df['about_product'])
df['user_id'] = le_user_id.fit_transform(df['user_id'])
df['review_title'] = le_review_title.fit_transform(df['review_title'])
df['img_link'] = le_img_link.fit_transform(df['img_link'])
df['product_link'] = le_product_link.fit_transform(df['product_link'])

# %% [markdown]
# ### Heatmap

# %%
# Plot correlations between variables
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()
